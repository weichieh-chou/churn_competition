# %%
import pandas as pd
from pathlib import Path
import numpy as np

DATA_DIR = Path("data/processing_checkpoint")
path_clean_dataset = DATA_DIR / "01_cleaned_train.parquet"

df_clean_churn = pd.read_parquet(path_clean_dataset)
df_clean_churn.dtypes
# Out:
# gender                     category
# level                      category
# userId                        int64
# page                       category
# sessionId                     int64
# itemInSession                 int64
# length                      float64
# song                       category
# artist                     category
# time                 datetime64[us]
# registration         datetime64[us]
# metropolitan_area          category
# region                     category
# operating_system           category
# browser                    category
# dtype: object

# %%
df_clean_churn.sample(5)
# Out:
#         gender level   userId             page  sessionId  itemInSession  \
# 4641982      M  paid  1745586         NextSong     139716             47
# 7332757      M  paid  1643057         NextSong     171836             34
# 2506367      M  paid  1388244         NextSong     135862             42
# 7665500      M  paid  1892313         NextSong     139161              8
# 6245344      M  paid  1212267  Add to Playlist      81928             33
#
#             length                   song                  artist  \
# 4641982  162.19383         I'm Diggin' It          Alecia Elliott
# 7332757  215.87546                   Evil                Interpol
# 2506367  316.94322      Static_ Oh Static  Mixtapes And Cellmates
# 7665500  346.48771  Perfecting Loneliness          Jets To Brazil
# 6245344    0.00000                No song               No artist
#
#                        time        registration  \
# 4641982 2018-10-30 22:40:59 2018-09-11 16:31:59
# 7332757 2018-11-09 13:02:11 2018-09-30 12:22:38
# 2506367 2018-10-30 02:23:57 2018-09-15 05:54:30
# 7665500 2018-11-07 01:02:13 2018-08-05 10:48:33
# 6245344 2018-10-19 17:48:31 2018-09-24 18:38:33
#
#                      metropolitan_area    region operating_system  browser
# 4641982       Chicago-Naperville-Elgin  IL-IN-WI           iPhone   Safari
# 7332757  San Francisco-Oakland-Hayward        CA             iPad   Safari
# 2506367           Beaumont-Port Arthur        TX          Windows  Firefox
# 7665500                      El Dorado        AR          Windows  Firefox
# 6245344                         Mobile        AL          Windows   Chrome

# %%
min_time = df_clean_churn["time"].min()
max_time = df_clean_churn["time"].max()

min_time, max_time
# Out:
# (Timestamp('2018-10-01 00:00:01'), Timestamp('2018-11-20 00:00:00'))

# %%
df_clean_churn["day"] = (df_clean_churn["time"] - min_time).dt.days

min_day = df_clean_churn["day"].min()
max_day = df_clean_churn["day"].max()

min_day, max_day
# Out:
# (0, 49)

# %%
# find user churn events
df_churn_events = df_clean_churn[
    df_clean_churn["page"] == "Cancellation Confirmation"
]

# userId → churn_day
user_churn_day = df_churn_events.set_index("userId")["day"].astype("float")

user_churn_day.sample(5)
# Out:
# userId
# 1908228    18.0
# 1806168    37.0
# 1381416    36.0
# 1364740    28.0
# 1610953     2.0
# Name: day, dtype: float64

# %%
window_size = 10
T_values = list(range(max_day - window_size, -1, -window_size))

T_values
# Out:
# [39, 29, 19, 9]

# %%
T = 39
df_window = df_clean_churn[df_clean_churn["day"] <= T].copy()


len(df_window)
# Out:
# 14480064

# %%
print(df_window.head())
# Out:
#   gender level   userId      page  sessionId  itemInSession     length  \
# 0      M  paid  1749042  NextSong      22683            278  524.32934
# 1      M  paid  1749042  NextSong      22683            279  178.02404
# 2      M  paid  1749042  NextSong      22683            280  232.61995
# 3      M  paid  1749042  NextSong      22683            281  265.50812
# 4      M  paid  1749042  NextSong      22683            282  471.69261
#
#                                      song                 artist  \
# 0  Ich mache einen Spiegel - Dream Part 4              Popol Vuh
# 1                 Monster (Album Version)                Skillet
# 2                       Seven Nation Army      The White Stripes
# 3        Under The Bridge (Album Version)  Red Hot Chili Peppers
# 4                            Circlesong 6         Bobby McFerrin
#
#                  time        registration            metropolitan_area region  \
# 0 2018-10-01 00:00:01 2018-08-08 13:22:21  Dallas-Fort Worth-Arlington     TX
# 1 2018-10-01 00:08:45 2018-08-08 13:22:21  Dallas-Fort Worth-Arlington     TX
# 2 2018-10-01 00:11:43 2018-08-08 13:22:21  Dallas-Fort Worth-Arlington     TX
# 3 2018-10-01 00:15:35 2018-08-08 13:22:21  Dallas-Fort Worth-Arlington     TX
# 4 2018-10-01 00:20:00 2018-08-08 13:22:21  Dallas-Fort Worth-Arlington     TX
#
#   operating_system browser  day
# 0          Windows  Chrome    0
# 1          Windows  Chrome    0
# 2          Windows  Chrome    0
# 3          Windows  Chrome    0
# 4          Windows  Chrome    0

# %%
def build_user_features(df_window):
    # Input: raw dataset where day <= cutoff day T
    # Output: user level features aggregated to day T

    # Base DataFrame
    df_users = (
        df_window[["userId", "gender", "registration", "operating_system", "browser"]]
        .drop_duplicates(subset=["userId"])
        .set_index("userId")
    )

    # Unique artist
    df_unique_artists = (
        df_window.groupby("userId")["artist"]
        .nunique()
        .rename("num_unique_artists")
    )
    df_users = df_users.join(df_unique_artists)

    # Page counts
    df_page_counts = (
        df_window.groupby("userId")["page"]
        .value_counts()
        .unstack(fill_value=0)
    )
    df_page_counts.columns = [
        f"count_{col.replace(' ', '_').lower()}" for col in df_page_counts.columns
    ]

    df_users = df_users.join(df_page_counts)


    # Total session count
    df_session_count = (
        df_window.groupby("userId")["sessionId"]
        .nunique()
        .rename("count_total_sessions")
    )
    df_users = df_users.join(df_session_count)

    # Lifecycle (hours)
    df_last_time = (
        df_window.groupby("userId")["time"]
        .max()
        .rename("last_time")
    )
    df_users = df_users.join(df_last_time)

    df_users["user_lifecycle_h"] = (
        (df_users["last_time"] - df_users["registration"]).dt.total_seconds() / 3600
    )

    # Total length
    df_length = (
        df_window.groupby("userId")["length"]
        .sum()
        .rename("ttl_length")
    )
    df_users = df_users.join(df_length)

    # Items per session
    df_item_per_session = (
        df_window.groupby("userId")["itemInSession"].max()
        / df_users["count_total_sessions"]
    )
    df_item_per_session = df_item_per_session.rename("item_per_session")
    df_users = df_users.join(df_item_per_session)

    # Frequency (sessions per user life cycle in hours

    df_users["frequency"] = (
        df_users["count_total_sessions"] / df_users["user_lifecycle_h"]
    )

    # avg songs per session
    if "count_nextsong" in df_users.columns:
        df_users["avg_songs_session"] = (
            df_users["count_nextsong"] / df_users["count_total_sessions"]
        )
    else:
        df_users["avg_songs_session"] = 0

    # Thumbs_up/down ratios
    df_users["thumbs_ratio"] = df_users["count_thumbs_up"] / (df_users["count_thumbs_down"] + df_users["count_thumbs_up"])
    df_users["thumbs_ratio"] = df_users["thumbs_ratio"].fillna(0)
    df_users["thumbs_ratio"] = df_users["thumbs_ratio"].replace(np.inf, 0)

    # Errors per session
    if "count_error" in df_users.columns:
        df_users["errors_per_session"] = (
            df_users["count_error"] / df_users["count_total_sessions"]
        )
    else:
        df_users["errors_per_session"] = 0

    # Ads per session
    if "count_roll_advert" in df_users.columns:
        df_users["ads_per_session"] = (
            df_users["count_roll_advert"] / df_users["count_total_sessions"]
        )
    else:
        df_users["ads_per_session"] = 0

    # Last Level (of paid or free)
    df_last_level = (
    df_clean_churn.groupby("userId")["level"]
    .last()
    .rename("last_level")
    )
    df_users = df_users.join(df_last_level)


    return df_users

# %%
build_user_features(df_window)
# Out:
#         gender        registration operating_system  browser  \
# userId
# 1749042      M 2018-08-08 13:22:21          Windows   Chrome
# 1563081      F 2018-09-21 03:25:18        Macintosh   Chrome
# 1697168      F 2018-09-08 13:48:25        Macintosh  Firefox
# 1222580      M 2018-08-16 02:31:00        Macintosh   Safari
# 1714398      F 2018-09-19 18:23:35          Windows   Chrome
# ...        ...                 ...              ...      ...
# 1418744      F 2018-10-22 13:27:55        Macintosh   Safari
# 1934047      M 2018-08-31 04:28:43        Macintosh   Chrome
# 1205281      F 2018-09-26 17:21:05             iPad   Safari
# 1266866      F 2018-09-14 22:37:16          Windows  Firefox
# 1668706      F 2018-08-27 08:53:07        Macintosh   Chrome
#
#          num_unique_artists  count_about  count_add_friend  \
# userId
# 1749042                 797            5                18
# 1563081                 437            1                 5
# 1697168                 683            1                 9
# 1222580                1252            8                35
# 1714398                 959            0                20
# ...                     ...          ...               ...
# 1418744                  87            0                 3
# 1934047                 271            0                 3
# 1205281                  88            0                 0
# 1266866                   3            0                 0
# 1668706                  38            1                 0
#
#          count_add_to_playlist  count_cancel  count_cancellation_confirmation  \
# userId
# 1749042                     33             1                                1
# 1563081                     14             0                                0
# 1697168                     21             0                                0
# 1222580                     50             1                                1
# 1714398                     46             0                                0
# ...                        ...           ...                              ...
# 1418744                      5             0                                0
# 1934047                     11             0                                0
# 1205281                      5             0                                0
# 1266866                      0             0                                0
# 1668706                      1             0                                0
#
#          ...           last_time  user_lifecycle_h    ttl_length  \
# userId   ...
# 1749042  ... 2018-10-21 01:16:24       1763.900833  256456.28661
# 1563081  ... 2018-11-03 02:00:13       1030.581944  123645.65861
# 1697168  ... 2018-11-09 13:10:30       1487.368056  213208.87262
# 1222580  ... 2018-10-30 23:17:30       1820.775000  452234.08024
# 1714398  ... 2018-11-03 00:29:30       1062.098611  321970.48842
# ...      ...                 ...               ...           ...
# 1418744  ... 2018-11-09 07:44:45        426.280556   22066.22015
# 1934047  ... 2018-11-09 23:57:32       1699.480278   73805.63500
# 1205281  ... 2018-11-09 18:08:22       1056.788056   21789.76404
# 1266866  ... 2018-11-09 11:27:54       1332.843889     382.48399
# 1668706  ... 2018-11-09 23:58:43       1791.093333    8611.01340
#
#          item_per_session  frequency  avg_songs_session  thumbs_ratio  \
# userId
# 1749042         51.444444   0.005102         113.777778      0.850000
# 1563081         29.666667   0.005822          82.833333      0.833333
# 1697168          5.555556   0.018153          31.962963      0.866667
# 1222580         25.650000   0.010984          89.650000      0.833333
# 1714398         34.800000   0.009415         128.100000      0.780488
# ...                   ...        ...                ...           ...
# 1418744        130.000000   0.002346          87.000000      0.857143
# 1934047        353.000000   0.000588         290.000000      0.791667
# 1205281         48.500000   0.001893          46.000000      1.000000
# 1266866          3.000000   0.000750           2.000000      1.000000
# 1668706         48.000000   0.000558          37.000000      0.750000
#
#          errors_per_session  ads_per_session  last_level
# userId
# 1749042            0.000000         0.000000        paid
# 1563081            0.000000         0.000000        paid
# 1697168            0.037037         2.185185        paid
# 1222580            0.150000         0.850000        paid
# 1714398            0.100000         0.300000        paid
# ...                     ...              ...         ...
# 1418744            0.000000         5.000000        free
# 1934047            2.000000         1.000000        paid
# 1205281            0.000000         5.000000        free
# 1266866            0.000000         0.000000        paid
# 1668706            0.000000         4.000000        free
#
# [18880 rows x 35 columns]

# %%
print(build_user_features(df_window).dtypes)
# Out:
# gender                                   category
# registration                       datetime64[us]
# operating_system                         category
# browser                                  category
# num_unique_artists                          int64
# count_about                                 int64
# count_add_friend                            int64
# count_add_to_playlist                       int64
# count_cancel                                int64
# count_cancellation_confirmation             int64
# count_downgrade                             int64
# count_error                                 int64
# count_help                                  int64
# count_home                                  int64
# count_logout                                int64
# count_nextsong                              int64
# count_roll_advert                           int64
# count_save_settings                         int64
# count_settings                              int64
# count_submit_downgrade                      int64
# count_submit_upgrade                        int64
# count_thumbs_down                           int64
# count_thumbs_up                             int64
# count_upgrade                               int64
# count_total_sessions                        int64
# last_time                          datetime64[us]
# user_lifecycle_h                          float64
# ttl_length                                float64
# item_per_session                          float64
# frequency                                 float64
# avg_songs_session                         float64
# thumbs_ratio                              float64
# errors_per_session                        float64
# ads_per_session                           float64
# last_level                               category
# dtype: object

# %%
def add_label(df_users, user_churn_day, T, window_size=10):

    df_users["churn_day"] = user_churn_day.astype("float")

    df_users["label"] = 0

    T_end_window = T + window_size

    churn_in_window_mask = ((df_users["churn_day"] > T) & (df_users["churn_day"] <= T_end_window))
    df_users.loc[churn_in_window_mask, "label"] = 1

    df_users = df_users[df_users["churn_day"].isna() | (df_users["churn_day"] > T)].copy()

    df_users["label"] = df_users["label"].fillna(0).astype(int)

    return df_users

# %%
df_users_T39 = build_user_features(df_window)
df_users_T39.head()
df_users_T39.shape
# Out:
# (18880, 35)

# %%
df_users_T39 = add_label(df_users_T39, user_churn_day, T=39)

# %%
df_users_T39["snapshot_day"] = 39
df_users_T39 = df_users_T39.reset_index()
df_users_T39
# Out:
#         userId gender        registration operating_system  browser  \
# 0      1563081      F 2018-09-21 03:25:18        Macintosh   Chrome
# 1      1697168      F 2018-09-08 13:48:25        Macintosh  Firefox
# 2      1714398      F 2018-09-19 18:23:35          Windows   Chrome
# 3      1010522      M 2018-09-22 07:49:20          Windows   Chrome
# 4      1475659      M 2018-09-10 07:17:33          Windows  Firefox
# ...        ...    ...                 ...              ...      ...
# 15271  1418744      F 2018-10-22 13:27:55        Macintosh   Safari
# 15272  1934047      M 2018-08-31 04:28:43        Macintosh   Chrome
# 15273  1205281      F 2018-09-26 17:21:05             iPad   Safari
# 15274  1266866      F 2018-09-14 22:37:16          Windows  Firefox
# 15275  1668706      F 2018-08-27 08:53:07        Macintosh   Chrome
#
#        num_unique_artists  count_about  count_add_friend  \
# 0                     437            1                 5
# 1                     683            1                 9
# 2                     959            0                20
# 3                    1034            4                14
# 4                     734            3                19
# ...                   ...          ...               ...
# 15271                  87            0                 3
# 15272                 271            0                 3
# 15273                  88            0                 0
# 15274                   3            0                 0
# 15275                  38            1                 0
#
#        count_add_to_playlist  count_cancel  ...  item_per_session  frequency  \
# 0                         14             0  ...         29.666667   0.005822
# 1                         21             0  ...          5.555556   0.018153
# 2                         46             0  ...         34.800000   0.009415
# 3                         44             0  ...         15.240000   0.021916
# 4                         24             0  ...         24.818182   0.007963
# ...                      ...           ...  ...               ...        ...
# 15271                      5             0  ...        130.000000   0.002346
# 15272                     11             0  ...        353.000000   0.000588
# 15273                      5             0  ...         48.500000   0.001893
# 15274                      0             0  ...          3.000000   0.000750
# 15275                      1             0  ...         48.000000   0.000558
#
#        avg_songs_session  thumbs_ratio  errors_per_session  ads_per_session  \
# 0              82.833333      0.833333            0.000000         0.000000
# 1              31.962963      0.866667            0.037037         2.185185
# 2             128.100000      0.780488            0.100000         0.300000
# 3              58.240000      0.829787            0.120000         1.880000
# 4              83.636364      0.836364            0.000000         0.272727
# ...                  ...           ...                 ...              ...
# 15271          87.000000      0.857143            0.000000         5.000000
# 15272         290.000000      0.791667            2.000000         1.000000
# 15273          46.000000      1.000000            0.000000         5.000000
# 15274           2.000000      1.000000            0.000000         0.000000
# 15275          37.000000      0.750000            0.000000         4.000000
#
#        last_level  churn_day  label  snapshot_day
# 0            paid        NaN      0            39
# 1            paid        NaN      0            39
# 2            paid        NaN      0            39
# 3            free        NaN      0            39
# 4            paid        NaN      0            39
# ...           ...        ...    ...           ...
# 15271        free        NaN      0            39
# 15272        paid        NaN      0            39
# 15273        free        NaN      0            39
# 15274        paid        NaN      0            39
# 15275        free        NaN      0            39
#
# [15276 rows x 39 columns]

# %%
user_churn_day.dtype
# Out:
# dtype('float64')

# %%
print(user_churn_day.head())
print(user_churn_day.dtype)
user_churn_day.index.is_unique
# Out:
# userId
# 1749042    20.0
# 1222580    29.0
# 1385500    47.0
# 1032628     0.0
# 1009070     2.0
# Name: day, dtype: float64
# float64
# True

# %%
def build_training_dataset(df_clean_churn, user_churn_day, T_values, window_size=10):

    all_snapshots = []

    for T in T_values:
        print(f"Processing snapshot for T = {T} ...")

        # filter window
        df_window = df_clean_churn[df_clean_churn["day"] <= T].copy()

        # build features
        df_features = build_user_features(df_window)

        # add labels
        df_labeled = add_label(df_features, user_churn_day, T=T, window_size=window_size)

        # add snapshot day column
        df_labeled["snapshot_day"] = T

        # reset index so userId becomes a column
        df_labeled = df_labeled.reset_index()

        # keep the snapshot
        all_snapshots.append(df_labeled)

    df_final = pd.concat(all_snapshots, axis = 0).reset_index(drop=True)

    return df_final

# %%
df_training = build_training_dataset(df_clean_churn, user_churn_day, T_values)
# Out:
# Processing snapshot for T = 39 ...
# Processing snapshot for T = 29 ...
# Processing snapshot for T = 19 ...
# Processing snapshot for T = 9 ...

# %%
df_training.head
# Out:
# <bound method NDFrame.head of         userId gender        registration operating_system  browser  \
# 0      1563081      F 2018-09-21 03:25:18        Macintosh   Chrome
# 1      1697168      F 2018-09-08 13:48:25        Macintosh  Firefox
# 2      1714398      F 2018-09-19 18:23:35          Windows   Chrome
# 3      1010522      M 2018-09-22 07:49:20          Windows   Chrome
# 4      1475659      M 2018-09-10 07:17:33          Windows  Firefox
# ...        ...    ...                 ...              ...      ...
# 60429  1208557      F 2018-08-02 15:05:09          Windows   Chrome
# 60430  1896647      F 2018-08-09 12:48:50          Windows   Chrome
# 60431  1494890      F 2018-09-14 03:15:14          Windows   Chrome
# 60432  1729584      M 2018-09-14 18:30:17        Macintosh   Safari
# 60433  1878214      M 2018-08-04 03:43:33        Macintosh   Chrome
#
#        num_unique_artists  count_about  count_add_friend  \
# 0                     437            1                 5
# 1                     683            1                 9
# 2                     959            0                20
# 3                    1034            4                14
# 4                     734            3                19
# ...                   ...          ...               ...
# 60429                  26            1                 0
# 60430                  29            0                 0
# 60431                  26            0                 0
# 60432                   3            0                 0
# 60433                  16            0                 3
#
#        count_add_to_playlist  count_cancel  ...  item_per_session  frequency  \
# 0                         14             0  ...         29.666667   0.005822
# 1                         21             0  ...          5.555556   0.018153
# 2                         46             0  ...         34.800000   0.009415
# 3                         44             0  ...         15.240000   0.021916
# 4                         24             0  ...         24.818182   0.007963
# ...                      ...           ...  ...               ...        ...
# 60429                      0             0  ...         38.000000   0.000601
# 60430                      3             0  ...         40.000000   0.000667
# 60431                      1             0  ...         25.000000   0.001551
# 60432                      0             0  ...          5.000000   0.001592
# 60433                      0             0  ...         27.000000   0.000614
#
#        avg_songs_session  thumbs_ratio  errors_per_session  ads_per_session  \
# 0              82.833333      0.833333            0.000000         0.000000
# 1              31.962963      0.866667            0.037037         2.185185
# 2             128.100000      0.780488            0.100000         0.300000
# 3              58.240000      0.829787            0.120000         1.880000
# 4              83.636364      0.836364            0.000000         0.272727
# ...                  ...           ...                 ...              ...
# 60429          25.000000      1.000000            0.000000         0.000000
# 60430          28.000000      0.800000            0.000000         0.000000
# 60431          25.000000      0.000000            0.000000         0.000000
# 60432           2.000000      0.000000            0.000000         0.000000
# 60433          15.000000      0.000000            0.000000         1.000000
#
#        last_level  churn_day  label  snapshot_day
# 0            paid        NaN      0            39
# 1            paid        NaN      0            39
# 2            paid        NaN      0            39
# 3            free        NaN      0            39
# 4            paid        NaN      0            39
# ...           ...        ...    ...           ...
# 60429        paid        NaN      0             9
# 60430        paid        NaN      0             9
# 60431        paid        NaN      0             9
# 60432        free        NaN      0             9
# 60433        paid        NaN      0             9
#
# [60434 rows x 39 columns]>

# %%
df_training["snapshot_day"].value_counts()
# Out:
# snapshot_day
# 29    15530
# 19    15452
# 39    15276
# 9     14176
# Name: count, dtype: int64

# %%
df_training["label"].value_counts()
# Out:
# label
# 0    57344
# 1     3090
# Name: count, dtype: int64

# %%
df_training.head()
# Out:
#     userId gender        registration operating_system  browser  \
# 0  1563081      F 2018-09-21 03:25:18        Macintosh   Chrome
# 1  1697168      F 2018-09-08 13:48:25        Macintosh  Firefox
# 2  1714398      F 2018-09-19 18:23:35          Windows   Chrome
# 3  1010522      M 2018-09-22 07:49:20          Windows   Chrome
# 4  1475659      M 2018-09-10 07:17:33          Windows  Firefox
#
#    num_unique_artists  count_about  count_add_friend  count_add_to_playlist  \
# 0                 437            1                 5                     14
# 1                 683            1                 9                     21
# 2                 959            0                20                     46
# 3                1034            4                14                     44
# 4                 734            3                19                     24
#
#    count_cancel  ...  item_per_session  frequency  avg_songs_session  \
# 0             0  ...         29.666667   0.005822          82.833333
# 1             0  ...          5.555556   0.018153          31.962963
# 2             0  ...         34.800000   0.009415         128.100000
# 3             0  ...         15.240000   0.021916          58.240000
# 4             0  ...         24.818182   0.007963          83.636364
#
#    thumbs_ratio  errors_per_session  ads_per_session  last_level  churn_day  \
# 0      0.833333            0.000000         0.000000        paid        NaN
# 1      0.866667            0.037037         2.185185        paid        NaN
# 2      0.780488            0.100000         0.300000        paid        NaN
# 3      0.829787            0.120000         1.880000        free        NaN
# 4      0.836364            0.000000         0.272727        paid        NaN
#
#    label  snapshot_day
# 0      0            39
# 1      0            39
# 2      0            39
# 3      0            39
# 4      0            39
#
# [5 rows x 39 columns]

# %%
PROCESSED_DATA_DIR = Path("data/processing_checkpoint")
checkpoint_file_path = PROCESSED_DATA_DIR / "03_10_day_window_sliced.parquet"
df_training.to_parquet(checkpoint_file_path, index=False)

# %%
df_training[df_training["label"]==1]
# Out:
#         userId gender        registration operating_system  browser  \
# 7      1385500      M 2018-08-16 04:30:35            Linux   Chrome
# 17     1240184      M 2018-09-19 18:34:21            Linux  Firefox
# 30     1418529      F 2018-09-21 19:27:33          Windows  Firefox
# 41     1642905      F 2018-07-22 13:15:58          Windows  Firefox
# 95     1475989      M 2018-09-22 00:09:18          Windows   Chrome
# ...        ...    ...                 ...              ...      ...
# 59881  1138673      F 2018-09-30 13:33:20        Macintosh   Chrome
# 59896  1081063      M 2018-09-29 13:39:28          Windows   Chrome
# 60035  1172943      F 2018-08-04 20:35:20        Macintosh   Safari
# 60179  1099753      F 2018-09-15 08:48:59          Windows   Chrome
# 60181  1253823      F 2018-07-24 02:58:08        Macintosh   Chrome
#
#        num_unique_artists  count_about  count_add_friend  \
# 7                    1433            4                47
# 17                   2444            8                82
# 30                   1805            9                57
# 41                   1336            5                46
# 95                   1838           12                50
# ...                   ...          ...               ...
# 59881                 456            1                 2
# 59896                 341            0                 1
# 60035                  20            0                 1
# 60179                  38            0                 0
# 60181                  97            0                 1
#
#        count_add_to_playlist  count_cancel  ...  item_per_session  frequency  \
# 7                         72             0  ...         18.863636   0.010682
# 17                       153             0  ...         13.771930   0.046791
# 30                        76             0  ...         16.538462   0.022681
# 41                        50             0  ...         45.500000   0.005370
# 95                       104             0  ...         15.736842   0.032391
# ...                      ...           ...  ...               ...        ...
# 59881                     14             0  ...         46.500000   0.025131
# 59896                     16             0  ...         23.500000   0.022411
# 60035                      1             0  ...         26.000000   0.000681
# 60179                      0             0  ...          8.333333   0.004878
# 60181                      4             0  ...        108.000000   0.000554
#
#        avg_songs_session  thumbs_ratio  errors_per_session  ads_per_session  \
# 7              99.863636      0.860870            0.090909         0.818182
# 17             81.070175      0.864151            0.070175         1.087719
# 30            114.269231      0.839779            0.038462         0.538462
# 41            140.000000      0.771186            0.071429         0.000000
# 95             83.973684      0.857923            0.052632         1.368421
# ...                  ...           ...                 ...              ...
# 59881          90.666667      0.813559            0.000000         0.166667
# 59896          65.666667      0.900000            0.500000         1.833333
# 60035          19.000000      0.500000            0.000000         1.000000
# 60179          12.333333      1.000000            0.000000         0.666667
# 60181          96.000000      0.666667            0.000000         1.000000
#
#        last_level  churn_day  label  snapshot_day
# 7            paid       47.0      1            39
# 17           paid       44.0      1            39
# 30           paid       41.0      1            39
# 41           paid       43.0      1            39
# 95           paid       45.0      1            39
# ...           ...        ...    ...           ...
# 59881        paid       19.0      1             9
# 59896        paid       16.0      1             9
# 60035        free       17.0      1             9
# 60179        paid       11.0      1             9
# 60181        paid       18.0      1             9
#
# [3090 rows x 39 columns]

# %%
df_training[df_training["userId"]==1099753]
# Out:
#         userId gender        registration operating_system browser  \
# 60179  1099753      F 2018-09-15 08:48:59          Windows  Chrome
#
#        num_unique_artists  count_about  count_add_friend  \
# 60179                  38            0                 0
#
#        count_add_to_playlist  count_cancel  ...  item_per_session  frequency  \
# 60179                      0             0  ...          8.333333   0.004878
#
#        avg_songs_session  thumbs_ratio  errors_per_session  ads_per_session  \
# 60179          12.333333           1.0                 0.0         0.666667
#
#        last_level  churn_day  label  snapshot_day
# 60179        paid       11.0      1             9
#
# [1 rows x 39 columns]

# %%
df_training[df_training["userId"]==1749042]
# Out:
#         userId gender        registration operating_system browser  \
# 30806  1749042      M 2018-08-08 13:22:21          Windows  Chrome
# 46258  1749042      M 2018-08-08 13:22:21          Windows  Chrome
#
#        num_unique_artists  count_about  count_add_friend  \
# 30806                 787            5                18
# 46258                 417            2                 7
#
#        count_add_to_playlist  count_cancel  ...  item_per_session  frequency  \
# 30806                     31             0  ...         51.444444   0.005106
# 46258                     13             0  ...         54.000000   0.003941
#
#        avg_songs_session  thumbs_ratio  errors_per_session  ads_per_session  \
# 30806         112.333333      0.847458                 0.0              0.0
# 46258          81.000000      0.750000                 0.0              0.0
#
#        last_level  churn_day  label  snapshot_day
# 30806        paid       20.0      1            19
# 46258        paid       20.0      0             9
#
# [2 rows x 39 columns]

# %%
df_training[df_training["label"]==0]
# Out:
#         userId gender        registration operating_system  browser  \
# 0      1563081      F 2018-09-21 03:25:18        Macintosh   Chrome
# 1      1697168      F 2018-09-08 13:48:25        Macintosh  Firefox
# 2      1714398      F 2018-09-19 18:23:35          Windows   Chrome
# 3      1010522      M 2018-09-22 07:49:20          Windows   Chrome
# 4      1475659      M 2018-09-10 07:17:33          Windows  Firefox
# ...        ...    ...                 ...              ...      ...
# 60429  1208557      F 2018-08-02 15:05:09          Windows   Chrome
# 60430  1896647      F 2018-08-09 12:48:50          Windows   Chrome
# 60431  1494890      F 2018-09-14 03:15:14          Windows   Chrome
# 60432  1729584      M 2018-09-14 18:30:17        Macintosh   Safari
# 60433  1878214      M 2018-08-04 03:43:33        Macintosh   Chrome
#
#        num_unique_artists  count_about  count_add_friend  \
# 0                     437            1                 5
# 1                     683            1                 9
# 2                     959            0                20
# 3                    1034            4                14
# 4                     734            3                19
# ...                   ...          ...               ...
# 60429                  26            1                 0
# 60430                  29            0                 0
# 60431                  26            0                 0
# 60432                   3            0                 0
# 60433                  16            0                 3
#
#        count_add_to_playlist  count_cancel  ...  item_per_session  frequency  \
# 0                         14             0  ...         29.666667   0.005822
# 1                         21             0  ...          5.555556   0.018153
# 2                         46             0  ...         34.800000   0.009415
# 3                         44             0  ...         15.240000   0.021916
# 4                         24             0  ...         24.818182   0.007963
# ...                      ...           ...  ...               ...        ...
# 60429                      0             0  ...         38.000000   0.000601
# 60430                      3             0  ...         40.000000   0.000667
# 60431                      1             0  ...         25.000000   0.001551
# 60432                      0             0  ...          5.000000   0.001592
# 60433                      0             0  ...         27.000000   0.000614
#
#        avg_songs_session  thumbs_ratio  errors_per_session  ads_per_session  \
# 0              82.833333      0.833333            0.000000         0.000000
# 1              31.962963      0.866667            0.037037         2.185185
# 2             128.100000      0.780488            0.100000         0.300000
# 3              58.240000      0.829787            0.120000         1.880000
# 4              83.636364      0.836364            0.000000         0.272727
# ...                  ...           ...                 ...              ...
# 60429          25.000000      1.000000            0.000000         0.000000
# 60430          28.000000      0.800000            0.000000         0.000000
# 60431          25.000000      0.000000            0.000000         0.000000
# 60432           2.000000      0.000000            0.000000         0.000000
# 60433          15.000000      0.000000            0.000000         1.000000
#
#        last_level  churn_day  label  snapshot_day
# 0            paid        NaN      0            39
# 1            paid        NaN      0            39
# 2            paid        NaN      0            39
# 3            free        NaN      0            39
# 4            paid        NaN      0            39
# ...           ...        ...    ...           ...
# 60429        paid        NaN      0             9
# 60430        paid        NaN      0             9
# 60431        paid        NaN      0             9
# 60432        free        NaN      0             9
# 60433        paid        NaN      0             9
#
# [57344 rows x 39 columns]

# %%
df_training[df_training["userId"]==1563081]
# Out:
#         userId gender        registration operating_system browser  \
# 0      1563081      F 2018-09-21 03:25:18        Macintosh  Chrome
# 15276  1563081      F 2018-09-21 03:25:18        Macintosh  Chrome
# 30807  1563081      F 2018-09-21 03:25:18        Macintosh  Chrome
# 46259  1563081      F 2018-09-21 03:25:18        Macintosh  Chrome
#
#        num_unique_artists  count_about  count_add_friend  \
# 0                     437            1                 5
# 15276                 303            1                 4
# 30807                 104            0                 1
# 46259                  24            0                 0
#
#        count_add_to_playlist  count_cancel  ...  item_per_session  frequency  \
# 0                         14             0  ...         29.666667   0.005822
# 15276                      8             0  ...         33.250000   0.004228
# 30807                      1             0  ...         51.500000   0.002924
# 46259                      0             0  ...         36.000000   0.004197
#
#        avg_songs_session  thumbs_ratio  errors_per_session  ads_per_session  \
# 0              82.833333      0.833333                 0.0              0.0
# 15276          82.250000      0.705882                 0.0              0.0
# 30807          55.500000      0.500000                 0.0              0.0
# 46259          25.000000      1.000000                 0.0              0.0
#
#        last_level  churn_day  label  snapshot_day
# 0            paid        NaN      0            39
# 15276        paid        NaN      0            29
# 30807        paid        NaN      0            19
# 46259        paid        NaN      0             9
#
# [4 rows x 39 columns]

# %%
df_training.isna().sum(
)
# Out:
# userId                                 0
# gender                                 0
# registration                           0
# operating_system                       0
# browser                                0
# num_unique_artists                     0
# count_about                            0
# count_add_friend                       0
# count_add_to_playlist                  0
# count_cancel                           0
# count_cancellation_confirmation        0
# count_downgrade                        0
# count_error                            0
# count_help                             0
# count_home                             0
# count_logout                           0
# count_nextsong                         0
# count_roll_advert                      0
# count_save_settings                    0
# count_settings                         0
# count_submit_downgrade                 0
# count_submit_upgrade                   0
# count_thumbs_down                      0
# count_thumbs_up                        0
# count_upgrade                          0
# count_total_sessions                   0
# last_time                              0
# user_lifecycle_h                       0
# ttl_length                             0
# item_per_session                       0
# frequency                              0
# avg_songs_session                      0
# thumbs_ratio                           0
# errors_per_session                     0
# ads_per_session                        0
# last_level                             0
# churn_day                          53178
# label                                  0
# snapshot_day                           0
# dtype: int64
