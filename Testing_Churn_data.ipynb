# %% [markdown]
# # First look at the data and gathering ideas for next steps

# %%
import pandas as pd

# %%
from pathlib import Path

DATA_DIR = Path("data/churn-prediction-25-26")
file_path_dataset = DATA_DIR / "train.parquet"

# %%
df_churn = pd.read_parquet(file_path_dataset)

# %%
df_churn.shape
# Out:
# (17499636, 19)

# %% [markdown]
# Massive dataset with 17_499_636 entries and 19 variables

# %%
df_churn.columns
# Out:
# Index(['status', 'gender', 'firstName', 'level', 'lastName', 'userId', 'ts',
#        'auth', 'page', 'sessionId', 'location', 'itemInSession', 'userAgent',
#        'method', 'length', 'song', 'artist', 'time', 'registration'],
#       dtype='object')

# %% [markdown]
# **Questions on meaning of variables:**
#
# What is ts?\
# What is the sessionId\
# What is itemInSession

# %%
df_churn.head(5)
# Out:
#       status gender firstName level lastName   userId             ts  \
# 0        200      M     Shlok  paid  Johnson  1749042  1538352001000
# 992      200      M     Shlok  paid  Johnson  1749042  1538352525000
# 1360     200      M     Shlok  paid  Johnson  1749042  1538352703000
# 1825     200      M     Shlok  paid  Johnson  1749042  1538352935000
# 2366     200      M     Shlok  paid  Johnson  1749042  1538353200000
#
#            auth      page  sessionId                         location  \
# 0     Logged In  NextSong      22683  Dallas-Fort Worth-Arlington, TX
# 992   Logged In  NextSong      22683  Dallas-Fort Worth-Arlington, TX
# 1360  Logged In  NextSong      22683  Dallas-Fort Worth-Arlington, TX
# 1825  Logged In  NextSong      22683  Dallas-Fort Worth-Arlington, TX
# 2366  Logged In  NextSong      22683  Dallas-Fort Worth-Arlington, TX
#
#       itemInSession                                          userAgent method  \
# 0               278  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...    PUT
# 992             279  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...    PUT
# 1360            280  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...    PUT
# 1825            281  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...    PUT
# 2366            282  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...    PUT
#
#          length                                    song  \
# 0     524.32934  Ich mache einen Spiegel - Dream Part 4
# 992   178.02404                 Monster (Album Version)
# 1360  232.61995                       Seven Nation Army
# 1825  265.50812        Under The Bridge (Album Version)
# 2366  471.69261                            Circlesong 6
#
#                      artist                time        registration
# 0                 Popol Vuh 2018-10-01 00:00:01 2018-08-08 13:22:21
# 992                 Skillet 2018-10-01 00:08:45 2018-08-08 13:22:21
# 1360      The White Stripes 2018-10-01 00:11:43 2018-08-08 13:22:21
# 1825  Red Hot Chili Peppers 2018-10-01 00:15:35 2018-08-08 13:22:21
# 2366         Bobby McFerrin 2018-10-01 00:20:00 2018-08-08 13:22:21

# %%
df_churn.sample(10)
# Out:
#           status gender firstName level   lastName   userId             ts  \
# 11230756     200      F   Delaney  paid      Kelly  1023234  1541226570000
# 2703188      200      F     Sofia  paid        Ali  1569568  1539095871000
# 8332045      200      F     Diana  paid    Collins  1663338  1540500296000
# 5514752      200      F   Makayla  paid   Bartlett  1327801  1539804466000
# 10170813     200      M     Brody  paid  Henderson  1157304  1540983782000
# 9507918      200      M     Caleb  paid   Richards  1143368  1540837008000
# 12882690     307      M    Samuel  paid   Phillips  1861316  1541685013000
# 14459103     307      M     Amari  paid      Nolan  1467482  1542123672000
# 1832877      200      M   Braylon  paid    Hendrix  1188019  1538834362000
# 1072327      200      F      Abby  free      Smith  1947193  1538637442000
#
#                auth         page  sessionId  \
# 11230756  Logged In     NextSong     134752
# 2703188   Logged In     NextSong      37973
# 8332045   Logged In     NextSong     110632
# 5514752   Logged In     NextSong      85480
# 10170813  Logged In     NextSong     141680
# 9507918   Logged In     NextSong     131351
# 12882690  Logged In    Thumbs Up     165145
# 14459103  Logged In  Thumbs Down     172349
# 1832877   Logged In     NextSong      21702
# 1072327   Logged In     NextSong      17413
#
#                                              location  itemInSession  \
# 11230756  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD             92
# 2703188                                   Greeley, CO             49
# 8332045                                Huntsville, AL             81
# 5514752                               Albuquerque, NM            281
# 10170813                                  Del Rio, TX              5
# 9507918            Los Angeles-Long Beach-Anaheim, CA            133
# 12882690      Sacramento--Roseville--Arden-Arcade, CA             63
# 14459103                        New Haven-Milford, CT              7
# 1832877                                 Lafayette, LA            150
# 1072327                                    Fresno, CA             20
#
#                                                   userAgent method     length  \
# 11230756  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...    PUT  231.28771
# 2703188   "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebK...    PUT  268.72118
# 8332045   "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...    PUT  247.09179
# 5514752   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_5...    PUT  273.10975
# 10170813  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.6; r...    PUT  256.96608
# 9507918   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...    PUT  204.90404
# 12882690  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...    PUT        NaN
# 14459103  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.6; r...    PUT        NaN
# 1832877   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...    PUT  337.16200
# 1072327   Mozilla/5.0 (Macintosh; Intel Mac OS X 10.6; r...    PUT  187.45424
#
#                                                        song  \
# 11230756                              Victoria (LP Version)
# 2703188                                          Mr. Freeze
# 8332045                                         God's Snake
# 5514752   Stylo (Album Version) (Feat. Mos Def and Bobby...
# 10170813  It Keeps You Runnin' (Album Version) (2006 Rem...
# 9507918                                    Stare At The Sun
# 12882690                                               None
# 14459103                                               None
# 1832877                                            Absynthe
# 1072327                                            Hands Up
#
#                                                artist                time  \
# 11230756                                     Old 97's 2018-11-03 06:29:30
# 2703188                                    K's Choice 2018-10-09 14:37:51
# 8332045                                        Samael 2018-10-25 20:44:56
# 5514752   Gorillaz Featuring Mos Def and Bobby Womack 2018-10-17 19:27:46
# 10170813                          The Doobie Brothers 2018-10-31 11:03:02
# 9507918                                        Thrice 2018-10-29 18:16:48
# 12882690                                         None 2018-11-08 13:50:13
# 14459103                                         None 2018-11-13 15:41:12
# 1832877                              Paul Kalkbrenner 2018-10-06 13:59:22
# 1072327                                       Soltero 2018-10-04 07:17:22
#
#                 registration
# 11230756 2018-09-24 11:17:53
# 2703188  2018-09-21 10:33:19
# 8332045  2018-09-12 10:18:46
# 5514752  2018-09-08 18:31:54
# 10170813 2018-09-27 01:46:52
# 9507918  2018-07-30 18:59:35
# 12882690 2018-08-16 12:22:30
# 14459103 2018-09-10 10:43:29
# 1832877  2018-08-15 17:52:50
# 1072327  2018-09-05 08:33:20

# %%
df_churn.describe()
# Out:
#              status            ts     sessionId  itemInSession        length  \
# count  1.749964e+07  1.749964e+07  1.749964e+07   1.749964e+07  1.429143e+07
# mean   2.091387e+02  1.540428e+12  8.480294e+04   1.055937e+02  2.487135e+02
# min    2.000000e+02  1.538352e+12  1.000000e+00   0.000000e+00  5.220000e-01
# 25%    2.000000e+02  1.539340e+12  2.515900e+04   2.600000e+01  1.998885e+02
# 50%    2.000000e+02  1.540397e+12  7.903800e+04   6.600000e+01  2.340828e+02
# 75%    2.000000e+02  1.541500e+12  1.383680e+05   1.440000e+02  2.768714e+02
# max    4.040000e+02  1.542672e+12  2.070030e+05   1.426000e+03  3.024666e+03
# std    3.023050e+01  1.233485e+09  6.141427e+04   1.168854e+02  9.722845e+01
#
#                              time                registration
# count                    17499636                    17499636
# mean   2018-10-25 00:47:01.161927  2018-08-25 04:40:21.543066
# min           2018-10-01 00:00:01         2017-10-14 22:05:25
# 25%    2018-10-12 10:33:57.750000         2018-08-10 21:14:59
# 50%           2018-10-24 15:58:54         2018-09-05 18:35:50
# 75%           2018-11-06 10:25:35         2018-09-20 17:24:57
# max           2018-11-20 00:00:00         2018-11-19 23:34:34
# std                           NaN                         NaN

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17499636 entries, 0 to 25661583
# Data columns (total 19 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   status         int64
#  1   gender         object
#  2   firstName      object
#  3   level          object
#  4   lastName       object
#  5   userId         object
#  6   ts             int64
#  7   auth           object
#  8   page           object
#  9   sessionId      int64
#  10  location       object
#  11  itemInSession  int64
#  12  userAgent      object
#  13  method         object
#  14  length         float64
#  15  song           object
#  16  artist         object
#  17  time           datetime64[us]
#  18  registration   datetime64[us]
# dtypes: datetime64[us](2), float64(1), int64(4), object(12)
# memory usage: 2.6+ GB

# %% [markdown]
# Times are already in datetime format\
# To change:\
# userId should be int

# %%
print("Unique Value Count")
few_unique_columns = []

for column_name in df_churn.columns:
    unique_count = df_churn[column_name].nunique()
    print(f"{column_name}: {unique_count}")
    if unique_count < 20:
        few_unique_columns.append(column_name)
# Out:
# Unique Value Count
# status: 3
# gender: 2
# firstName: 4967
# level: 2
# lastName: 1000
# userId: 19140
# ts: 4189091
# auth: 2
# page: 19
# sessionId: 161194
# location: 875
# itemInSession: 1427
# userAgent: 85
# method: 2
# length: 23379
# song: 239299
# artist: 37264
# time: 4189091
# registration: 19118

# %% [markdown]
# NaN and others:\
# length can be NaN, song and artist can be None

# %%
for column_name in few_unique_columns:
    unique_values = df_churn[column_name].unique()
    print(f"{column_name}: {unique_values}")
# Out:
# status: [200 307 404]
# gender: ['M' 'F']
# level: ['paid' 'free']
# auth: ['Logged In' 'Cancelled']
# page: ['NextSong' 'Downgrade' 'Help' 'Home' 'Thumbs Up' 'Add Friend'
#  'Thumbs Down' 'Add to Playlist' 'Logout' 'About' 'Settings'
#  'Save Settings' 'Cancel' 'Cancellation Confirmation' 'Submit Downgrade'
#  'Roll Advert' 'Upgrade' 'Error' 'Submit Upgrade']
# method: ['PUT' 'GET']

# %%
max_time = df_churn["time"].max()
min_time = df_churn["time"].min()
print(f"Time min and max = {min_time} - {max_time}")
# Out:
# Time min and max = 2018-10-01 00:00:01 - 2018-11-20 00:00:00

# %%
max_registration = df_churn["registration"].max()
min_registration = df_churn["registration"].min()
print(f"Registration min and max = {min_registration} - {max_registration}")
# Out:
# Registration min and max = 2017-10-14 22:05:25 - 2018-11-19 23:34:34

# %%
df_churn["page"].value_counts()
# Out:
# page
# NextSong                     14291433
# Thumbs Up                      789391
# Home                           645259
# Add to Playlist                409606
# Roll Advert                    284837
# Add Friend                     262147
# Logout                         204700
# Thumbs Down                    164964
# Downgrade                      124248
# Settings                       101191
# Help                            89035
# Upgrade                         37696
# About                           33117
# Save Settings                   20370
# Error                           17294
# Submit Upgrade                  11381
# Submit Downgrade                 4425
# Cancellation Confirmation        4271
# Cancel                           4271
# Name: count, dtype: int64

# %% [markdown]
# **Next steps from here:**
#
# - More in depth EDA
# - Data cleaning (missing values, fix data types, drop columns (like names), convert column entries to more useful readable stuff (like location, Useragent))
# - Aggregation (each entry belongs to a single user, user data has to be collectd together, goal is to have 1 row per user and at the end a label)
# - Preprocessing (Standardization on numerical features, Encoding on categorical features)

# %% [markdown]
# **Caching the data:**
#
# - we have a really big dataset so it makes sense to store the changed data after e.g. data cleaning
# - apparently the current format (parquet) is not the most efficient
# - Possible ways could be HDF5 (PyTables) or Feather (Arrow IPC)

# %% [markdown]
# **Next steps brainstorm:**
#
# - Define the label churn (1,0)
# - Data cleaning (delete invalid users, drop useless columns like name or method, convert e.g. ts, handle NaN values but not all delete e.g. artist is nan when no song is played)
# - String manipulation (for e.g. location or userAgent we can get better info than right now)
# - Think about aggregation strategy (one row per user, think about best way to aggregate current data)
# - Feature engineering (how long did user stay on service afer registration, behavior like thumbs up but basically all important "pages",...)
# - Preprocessing (encoding categorical text, scaling)
# - think about imbalance (e.g. F1 metric later, how to train best with little rate of churn,...)

# %% [markdown]
# **Ideas on how to work together:**
#
# - Will probbaly work in Jupyter Notebook (especially useful for EDA, maybe later in py file?)
# - not work in the same file!! Conflicts etc., 2 seperate "work files" and then master files where we later put the code together
# - Use relative paths only
# - Not forget .gitignore
# - maybe: loader script (same code always when loading the data), syny environments (different versions of e.g. pandas) - but not yet, if we need it

# %% [markdown]
# test push jessie

# %% [markdown]
# Benedikt test

# %% [markdown]
# Baksdfkasfasfjalksjfklajsfkjaslkjfkasjdf

# %% [markdown]
# asdfjasdjfaklsdfj

# %%
print("Benedikt Watrzinger")
# Out:
# Benedikt Watrzinger
